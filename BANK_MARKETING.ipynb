# %% [markdown]
# IMPORTING IMPORTANT LIBRARIES

# %%
#Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the data
train = pd.read_csv("/content/termdeposit_train.csv")
test = pd.read_csv("/content/termdeposit_test.csv")

# %% [markdown]
# Checking the columns of each dataset

# %%
train.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribed'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome'],
#       dtype='object')

# %% [markdown]
# Hence, 'Subscribed' is the target variable.

# %% [markdown]
# Checking the data types of the variables

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31647 entries, 0 to 31646
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          31647 non-null  int64
#  1   age         31647 non-null  int64
#  2   job         31647 non-null  object
#  3   marital     31647 non-null  object
#  4   education   31647 non-null  object
#  5   default     31647 non-null  object
#  6   balance     31647 non-null  int64
#  7   housing     31647 non-null  object
#  8   loan        31647 non-null  object
#  9   contact     31647 non-null  object
#  10  day         31647 non-null  int64
#  11  month       31647 non-null  object
#  12  duration    31647 non-null  int64
#  13  campaign    31647 non-null  int64
#  14  pdays       31647 non-null  int64
#  15  previous    31647 non-null  int64
#  16  poutcome    31647 non-null  object
#  17  subscribed  31647 non-null  object
# dtypes: int64(8), object(10)
# memory usage: 4.3+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13564 entries, 0 to 13563
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         13564 non-null  int64
#  1   age        13564 non-null  int64
#  2   job        13564 non-null  object
#  3   marital    13564 non-null  object
#  4   education  13564 non-null  object
#  5   default    13564 non-null  object
#  6   balance    13564 non-null  int64
#  7   housing    13564 non-null  object
#  8   loan       13564 non-null  object
#  9   contact    13564 non-null  object
#  10  day        13564 non-null  int64
#  11  month      13564 non-null  object
#  12  duration   13564 non-null  int64
#  13  campaign   13564 non-null  int64
#  14  pdays      13564 non-null  int64
#  15  previous   13564 non-null  int64
#  16  poutcome   13564 non-null  object
# dtypes: int64(8), object(9)
# memory usage: 1.8+ MB

# %%
train.shape
# Out:
# (31647, 18)

# %%
test.shape
# Out:
# (13564, 17)

# %% [markdown]
# Hence, we can see that we have 17 similar features in the both the dataset and 'Subscribed' is the variable that is to be predicted

# %% [markdown]
# DATA EXPLORATION

# %%
#Printing the first 5 rows of the train dataset
train.head()
# Out:
#       ID  age         job   marital  education default  balance housing loan  \
# 0  26110   56      admin.   married    unknown      no     1933      no   no
# 1  40576   31     unknown   married  secondary      no        3      no   no
# 2  15320   27    services   married  secondary      no      891     yes   no
# 3  43962   57  management  divorced   tertiary      no     3287      no   no
# 4  29842   31  technician   married  secondary      no      119     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# 1   cellular   20   jul        91         2     -1         0  unknown
# 2   cellular   18   jul       240         1     -1         0  unknown
# 3   cellular   22   jun       867         1     84         3  success
# 4   cellular    4   feb       380         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3        yes
# 4         no

# %%
#Printing the first 5 rows of the test dataset
test.head()
# Out:
#       ID  age            job   marital  education default  balance housing  \
# 0  38441   32       services   married  secondary      no      118     yes
# 1  40403   78        retired  divorced    primary      no     2787      no
# 2   3709   31  self-employed    single   tertiary      no      144     yes
# 3  37422   57       services    single    primary      no     3777     yes
# 4  12527   45    blue-collar  divorced  secondary      no     -705      no
#
#   loan    contact  day month  duration  campaign  pdays  previous poutcome
# 0   no   cellular   15   may        20         6     -1         0  unknown
# 1   no  telephone    1   jul       372         1     -1         0  unknown
# 2   no    unknown   16   may       676         1     -1         0  unknown
# 3   no  telephone   13   may        65         2     -1         0  unknown
# 4  yes    unknown    3   jul       111         1     -1         0  unknown

# %%
#checking for missing values in train dataset
train.isnull().sum()
# Out:
# ID            0
# age           0
# job           0
# marital       0
# education     0
# default       0
# balance       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# subscribed    0
# dtype: int64

# %%
#Checking for missing values in test dataset
test.isnull().sum()
# Out:
# ID           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %% [markdown]
# UNIVARIATE ANALYSIS

# %% [markdown]
# Analysis of 'Subscribed' variable

# %%
#Frequency of 'subscribed'
train['subscribed'].value_counts()
# Out:
# subscribed
# no     27932
# yes     3715
# Name: count, dtype: int64

# %%
# Plotting the 'subscribed' frequency
sns.countplot(data=train, x='subscribed')
# Out:
# <Axes: xlabel='subscribed', ylabel='count'>

# %%
#Normalizing the frequency table of 'Subscribed' variable
train['subscribed'].value_counts(normalize=True)
# Out:
# subscribed
# no     0.882611
# yes    0.117389
# Name: proportion, dtype: float64

# %% [markdown]
# From the above analysis we can see that only 3,715 people out of 31,647 have subscribed which is roughly 12%.

# %% [markdown]
# Analysing th 'Job' variable

# %%
#Frequency table
train['job'].value_counts()
# Out:
# job
# blue-collar      6842
# management       6639
# technician       5307
# admin.           3631
# services         2903
# retired          1574
# self-employed    1123
# entrepreneur     1008
# unemployed        905
# housemaid         874
# student           635
# unknown           206
# Name: count, dtype: int64

# %%
# Plotting the job frequency table
import seaborn as sns
sns.set_context('paper')
train['job'].value_counts().plot(kind='bar', figsize=(10,6))
# Out:
# <Axes: xlabel='job'>

# %% [markdown]
# We can see that most of the clients beloned to blue-collar job and students are least in general as they don't make term deposits in general.

# %% [markdown]
# Analysis of 'marital' status

# %%
train['marital'].value_counts()
# Out:
# marital
# married     19095
# single       8922
# divorced     3630
# Name: count, dtype: int64

# %%
sns.countplot(data=train, x='marital');

# %%
sns.countplot(data=train, x='marital', hue='subscribed');

# %% [markdown]
# Analyzing the 'age' variable

# %%
sns.distplot(train['age']);

# %% [markdown]
# We can infer that most of the clients fall in the age group between 20-60.

# %% [markdown]
# Bivariate Analysis

# %%
print(pd.crosstab(train["job"], train["subscribed"]))
# Out:
# subscribed       no  yes
# job
# admin.         3179  452
# blue-collar    6353  489
# entrepreneur    923   85
# housemaid       795   79
# management     5716  923
# retired        1212  362
# self-employed   983  140
# services       2649  254
# student         453  182
# technician     4713  594
# unemployed      776  129
# unknown         180   26

# %%
job = pd.crosstab(train['job'],train['subscribed'])
job_norm = job.div(job.sum(1).astype(float), axis=0)

# %%
job_norm.plot.bar(stacked=True,figsize=(8,6));

# %% [markdown]
# From the above graph we can infer that students and retired people have higher chances of subscribing to a term deposit, which is surprising as students generally do not subscribe to a term deposit. The possible reason is that the number of students in the dataset is less and comparatively to other job types, more students have subscribed to a term deposit.

# %%
#Marital status vs subscribed
pd.crosstab(train['marital'], train['subscribed'])
# Out:
# subscribed     no   yes
# marital
# divorced     3185   445
# married     17176  1919
# single       7571  1351

# %%
marital = pd.crosstab(train['marital'], train['subscribed'])
marital_norm = marital.div(marital.sum(1).astype(float), axis=0)
marital_norm
# Out:
# subscribed        no       yes
# marital
# divorced    0.877410  0.122590
# married     0.899502  0.100498
# single      0.848577  0.151423

# %%
marital_norm.plot.bar(stacked=True, figsize=(10,6));

# %% [markdown]
# From the above analysis we can infer that marital status doesn't have a major impact on the subscription to term deposits.

# %%
#default vs subscription
pd.crosstab(train['default'], train['subscribed'])
# Out:
# subscribed     no   yes
# default
# no          27388  3674
# yes           544    41

# %%
dflt = pd.crosstab(train['default'], train['subscribed'])
dflt_norm = dflt.div(dflt.sum(1).astype(float), axis=0)
dflt_norm
# Out:
# subscribed        no       yes
# default
# no          0.881720  0.118280
# yes         0.929915  0.070085

# %%
dflt_norm.plot.bar(stacked=True, figsize=(6,6))
# Out:
# <Axes: xlabel='default'>

# %% [markdown]
# We can infer that clients having no previous default have slightly higher chances of subscribing to a term loan as compared to the clients who have previous default history.

# %%
# Converting the target variables into 0s and 1s
train['subscribed'].replace('no', 0,inplace=True)
train['subscribed'].replace('yes', 1,inplace=True)

# %%
train['subscribed']
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 31642    0
# 31643    1
# 31644    0
# 31645    0
# 31646    1
# Name: subscribed, Length: 31647, dtype: int64

# %%
# Convert 'object' type columns to numerical using one-hot encoding
train = pd.get_dummies(train)

#Correlation matrix
corr = train.corr()
corr
# Out:
#                            ID       age   balance       day  duration  \
# ID                   1.000000  0.013337  0.067897 -0.063399  0.007183
# age                  0.013337  1.000000  0.103245 -0.011056 -0.003870
# balance              0.067897  0.103245  1.000000  0.003461  0.024274
# day                 -0.063399 -0.011056  0.003461  1.000000 -0.032288
# duration             0.007183 -0.003870  0.024274 -0.032288  1.000000
# campaign            -0.103508  0.005733 -0.012032  0.159168 -0.080305
# pdays                0.436148 -0.021947  0.001789 -0.087626  0.000529
# previous             0.254476  0.005761  0.013843 -0.048752  0.001783
# subscribed           0.296663  0.024538  0.050807 -0.029600  0.389838
# job_admin.           0.018790 -0.055530 -0.030051 -0.012114 -0.012764
# job_blue-collar     -0.121656 -0.046797 -0.051048 -0.017137  0.008423
# job_entrepreneur    -0.023663  0.023492  0.010833 -0.001104 -0.006705
# job_housemaid       -0.010610  0.090892  0.005893  0.005731 -0.011864
# job_management       0.055344 -0.021578  0.066619  0.015577 -0.003185
# job_retired          0.085450  0.444928  0.049422 -0.018080  0.029160
# job_self-employed    0.015529 -0.010433  0.021339  0.004502  0.008396
# job_services        -0.043359 -0.067485 -0.035848 -0.001764 -0.001233
# job_student          0.121191 -0.192511  0.002282 -0.014934 -0.005475
# job_technician      -0.005939 -0.068517 -0.015775  0.030681 -0.011540
# job_unemployed       0.023865 -0.000898  0.007583 -0.005324  0.018208
# month_sep            -0.014692   1.000000          0.033049        0.037212
# poutcome_failure      0.031381   0.033049          1.000000       -0.071013
# poutcome_other        0.030627   0.037212         -0.071013        1.000000
# poutcome_success      0.106412   0.116310         -0.064431       -0.038494
# poutcome_unknown     -0.090804  -0.100166         -0.734161       -0.438617
#
#                      poutcome_success  poutcome_unknown
# ID                           0.265963         -0.496277
# age                          0.029112         -0.000885
# balance                      0.028584         -0.027209
# day                         -0.028971          0.079794
# duration                     0.036574         -0.002768
# campaign                    -0.057645          0.107196
# pdays                        0.229305         -0.868844
# previous                     0.189952         -0.504232
# subscribed                   0.309125         -0.171144
# job_admin.                   0.016726         -0.031425
# job_blue-collar             -0.053518          0.028174
# job_entrepreneur            -0.019947          0.017831
# job_housemaid               -0.010139          0.022008
# job_management               0.020179         -0.007153
# job_retired                  0.055443         -0.024785
# job_self-employed            0.003880         -0.002262
# job_services                -0.020593          0.006691
# job_student                  0.051876         -0.047598
# job_technician              -0.006134          0.004149
# job_unemployed               0.008881          0.016515
# job_unknown                  0.004457          0.010437
# marital_divorced            -0.007415          0.001771
# marital_married             -0.023395          0.032249
# marital_single               0.030688         -0.036318
# education_primary           -0.033275          0.037686
# education_secondary         -0.026787         -0.002569
# education_tertiary           0.049981         -0.028753
# education_unknown            0.012856          0.004287
# default_no                   0.024348         -0.039447
# default_yes                 -0.024348          0.039447
# housing_no                   0.092410          0.055850
# housing_yes                 -0.092410         -0.055850
# loan_no                      0.054198         -0.027869
# loan_yes                    -0.054198          0.027869
# contact_cellular             0.104894         -0.264530
# contact_telephone            0.009191         -0.023088
# contact_unknown             -0.115576          0.291421
# month_apr                    0.018215         -0.136883
# month_aug                    0.000903          0.095298
# month_dec                    0.088918         -0.070875
# month_feb                    0.024266         -0.098910
# month_jan                    0.009134         -0.079518
# month_jul                   -0.045914          0.159035
# month_jun                   -0.022851          0.117151
# month_mar                    0.044780         -0.052590
# month_may                   -0.060896          0.003744
# month_nov                    0.008701         -0.091105
# month_oct                    0.106412         -0.090804
# month_sep                    0.116310         -0.100166
# poutcome_failure            -0.064431         -0.734161
# poutcome_other              -0.038494         -0.438617
# poutcome_success             1.000000         -0.397965
# poutcome_unknown            -0.397965          1.000000
#
# [53 rows x 53 columns]

# %%
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(corr, annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# We can infer that duration of the call is highly correlated with the target variable. As the duration of the call is more, there are higher chances that the client is showing interest in the term deposit and hence there are higher chances that the client will subscribe to term deposit.

# %% [markdown]
# Model Building

# %%
target = train['subscribed']
train = train.drop('subscribed', axis=1)

# %%
#generating dummy values on the train dataset
train = pd.get_dummies(train)
train.head()
# Out:
#       ID  age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 0  26110   56     1933   19        44         2     -1         0        True
# 1  40576   31        3   20        91         2     -1         0       False
# 2  15320   27      891   18       240         1     -1         0       False
# 3  43962   57     3287   22       867         1     84         3       False
# 4  29842   31      119    4       380         1     -1         0       False
#
#    job_blue-collar  ...  month_jun  month_mar  month_may  month_nov  \
# 0            False  ...      False      False      False       True
# 1            False  ...      False      False      False      False
# 2            False  ...      False      False      False      False
# 3            False  ...       True      False      False      False
# 4            False  ...      False      False      False      False
#
#    month_oct  month_sep  poutcome_failure  poutcome_other  poutcome_success  \
# 0      False      False             False           False             False
# 1      False      False             False           False             False
# 2      False      False             False           False             False
# 3      False      False             False           False              True
# 4      False      False             False           False             False
#
#    poutcome_unknown
# 0              True
# 1              True
# 2              True
# 3             False
# 4              True
#
# [5 rows x 52 columns]

# %% [markdown]
# Splitting the data into train and validation set such as to validate the results of our model on the validation set. keeping 20% of the dataset as our validation set and the rest as our training set.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size=0.2, random_state=12)

# %% [markdown]
# Now our data is ready and it's time to build our model and check its performance. Since it's a classification problem, I'll be using Logistic Regression model for this problem.

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
#creating an object of logistic regression model
lreg = LogisticRegression()

# %%
#fitting the data into the model
lreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#Making predictions on the validation set
pred = lreg.predict(X_val)

# %% [markdown]
# Checking the accuracy of our model

# %%
from sklearn.metrics import accuracy_score # Correct import statement

# %%
#Calculating the accuracy score
accuracy_score(y_val,pred)
# Out:
# 0.8908372827804107

# %% [markdown]
# We got an accuracy score of around 89% on the validation dataset. Logistic regression has a linear decision boundary. What if our data have non linearity? We need a model that can capture this non linearity.

# %% [markdown]
# Using Decision Tree algorithm to for dealing with non-linearity

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#creating an object of Decision tree
clf = DecisionTreeClassifier(max_depth=4, random_state=0)

# %%
#fitting the model
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=0)

# %%
#making predictions on the validation set
predict = clf.predict(X_val)
predict
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
#Calculating the accuracy
accuracy_score(y_val,predict)
# Out:
# 0.9042654028436019

# %% [markdown]
# We got an accuracy of more than 90% on the validation set.
#
# Let's now make the prediction on test dataset

# %%
test = pd.get_dummies(test)
test.head()
# Out:
#       ID  age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 0  38441   32      118   15        20         6     -1         0       False
# 1  40403   78     2787    1       372         1     -1         0       False
# 2   3709   31      144   16       676         1     -1         0       False
# 3  37422   57     3777   13        65         2     -1         0       False
# 4  12527   45     -705    3       111         1     -1         0       False
#
#    job_blue-collar  ...  month_jun  month_mar  month_may  month_nov  \
# 0            False  ...      False      False       True      False
# 1            False  ...      False      False      False      False
# 2            False  ...      False      False       True      False
# 3            False  ...      False      False       True      False
# 4             True  ...      False      False      False      False
#
#    month_oct  month_sep  poutcome_failure  poutcome_other  poutcome_success  \
# 0      False      False             False           False             False
# 1      False      False             False           False             False
# 2      False      False             False           False             False
# 3      False      False             False           False             False
# 4      False      False             False           False             False
#
#    poutcome_unknown
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
#
# [5 rows x 52 columns]

# %%
test_pred = clf.predict(test)
test_pred
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %% [markdown]
# Finally, we will save these predictions into a csv file.

# %%
submissions = pd.DataFrame()

# %%
submissions['ID'] = test['ID']
submissions['subscribed'] = test_pred

# %%
submissions['subscribed']
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 13559    0
# 13560    0
# 13561    0
# 13562    1
# 13563    0
# Name: subscribed, Length: 13564, dtype: int64

# %% [markdown]
# Since the target variable is yes or no, we will convert 1 and 0 in the predictions to yes and no respectively.

# %%
submissions['subscribed'].replace(0,'no',inplace=True)
submissions['subscribed'].replace(1,'yes',inplace=True)

# %%
submissions['subscribed']
# Out:
# 0         no
# 1        yes
# 2         no
# 3         no
# 4         no
#         ...
# 13559     no
# 13560     no
# 13561     no
# 13562    yes
# 13563     no
# Name: subscribed, Length: 13564, dtype: object

# %%
submissions.to_csv('submission file.csv', header=True, index=False)
